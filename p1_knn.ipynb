# %% [markdown]
# <a href="https://colab.research.google.com/github/anushrijamar/Machine_learning/blob/main/p1_knn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
df = pd.read_csv('/content/Seed_Data.csv')
X=df.iloc[:,0:7]
Y=df.iloc[:,7]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=21)
sc=StandardScaler();
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
from sklearn.neighbors import KNeighborsClassifier
clf=KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train,Y_train)
y_pred=clf.predict(X_test)
print(y_pred)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
print(cm)
k_values = []
accuracy_values = []

for k in range(1, 5):  # You can adjust the range of K as needed
    clf = KNeighborsClassifier(n_neighbors=k)
    clf.fit(X_train, Y_train)
    accuracy = clf.score(X_test, Y_test)
    k_values.append(k)
    accuracy_values.append(accuracy)
plt.figure(figsize=(4, 3))
print(accuracy_values)
plt.plot(k_values, accuracy_values, marker='o', linestyle='-')
plt.title('Accuracy vs. Number of Neighbors (K)')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
# Out:
# [0 0 0 0 0 2 1 2 2 1 0 1 1 0 1 2 1 2 2 0 2 1 2 0 1 0 2 0 1 2 1 1 1 2 1 2 2
#  2 2 0 0 2]
# [[12  0  2]
#  [ 0 13  0]
#  [ 1  0 14]]
# [0.9285714285714286, 0.9047619047619048, 0.9285714285714286, 0.9285714285714286]
